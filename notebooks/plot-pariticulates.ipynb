# %%
import pandas
from compare_temperatures.plot_temperatures import read_adafruit_feed_csv

# %%
start_dt = '2022-09-23'
pms = read_adafruit_feed_csv('data/particles-03um-20221010-1347.csv', 'pms0u3', start_dt)

# %%
pms
# Out:
#                      pms0u3
# created
# 2022-09-25 13:37:00     180
# 2022-09-25 13:38:00     141
# 2022-09-25 13:39:00     135
# 2022-09-25 13:40:00     243
# 2022-09-25 13:41:00     246
# ...                     ...
# 2022-10-10 13:42:00   25056
# 2022-10-10 13:43:00   24684
# 2022-10-10 13:44:00   22941
# 2022-10-10 13:45:00   24168
# 2022-10-10 13:46:00   24000
#
# [8389 rows x 1 columns]

# %%
pms.plot()
# Out:
# <AxesSubplot:xlabel='created'>
