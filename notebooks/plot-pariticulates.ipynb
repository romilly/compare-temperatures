# %%
import pandas
from compare_temperatures.plot_temperatures import read_adafruit_feed_csv

# %%
start_dt = '2022-09-23'
pms = read_adafruit_feed_csv('data/particles-03um-20221013-1049.csv', 'pms0u3', start_dt)

# %%
pms
# Out:
#                            pms0u3
# created
# 2022-09-25 13:37:00+00:00     180
# 2022-09-25 13:38:00+00:00     141
# 2022-09-25 13:39:00+00:00     135
# 2022-09-25 13:40:00+00:00     243
# 2022-09-25 13:41:00+00:00     246
# ...                           ...
# 2022-10-13 10:45:00+00:00     747
# 2022-10-13 10:46:00+00:00     450
# 2022-10-13 10:47:00+00:00     534
# 2022-10-13 10:48:00+00:00     441
# 2022-10-13 10:49:00+00:00     702
#
# [25466 rows x 1 columns]

# %%
pms.plot()
# Out:
# <AxesSubplot:xlabel='created'>
